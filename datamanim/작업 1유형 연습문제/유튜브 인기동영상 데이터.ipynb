# %% [markdown]
# 유튜브 인기동영상 데이터
# ===

# %% [markdown]
# Attention
# ===
#
# 데이터 출처 :https://www.kaggle.com/rsrishav/youtube-trending-video-dataset?select=KR_youtube_trending_data.csv
# 데이터 설명 : 유튜브 데일리 인기동영상 (한국)
# dataurl : https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv

# %%
import pandas as pd

dataurl = 'https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv'
df = pd.read_csv(dataurl, index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %% [markdown]
# **Question 1**
#
# 인기동영상 제작횟수가 많은 채널 상위 10개명을 출력하라. (날짜기준, 중복포함)

# %%
Ans = list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique())
Ans
# Out:
# ['장삐쭈',
#  '총몇명',
#  '파뿌리',
#  '짤툰',
#  '런닝맨 - 스브스 공식 채널',
#  '엠뚜루마뚜루 : MBC 공식 종합 채널',
#  'SPOTV',
#  '채널 십오야',
#  '이과장',
#  'BANGTANTV']

# %% [markdown]
# **Question 2**
#
# 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라.

# %%
Ans = list(df[df['dislikes'] > df['likes']].channelTitle.unique())
# Ans = list(df.loc[df.likes < df.dislikes.channelTitle.unique()])
Ans
# Out:
# ['핫도그TV',
#  'ASMR 애정TV',
#  '하얀트리HayanTree',
#  '양팡 YangPang',
#  '철구형 (CHULTUBE)',
#  '왜냐맨하우스',
#  '(MUTUBE)와꾸대장봉준',
#  '오메킴TV',
#  '육지담',
#  'MapleStory_KR',
#  'ROAD FIGHTING CHAMPIONSHIP',
#  '사나이 김기훈',
#  '나혼자산다 STUDIO',
#  'Gen.G esports']

# %% [markdown]
# **Question 3**
#
# 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라.

# %%
Ans = df.drop_duplicates(subset=['channelId', 'channelTitle']).channelId.value_counts()
len(Ans[Ans>1])
# Out:
# 71

# %% [markdown]
# **Question 4**
#
# 일요일에 인기있었던 영상들중 가장많은 영상 종류(categoryId)는 무엇인가?

# %%
# ✅
df['trending_date2'] = pd.to_datetime(df['trending_date2'])
answer = df.loc[df['trending_date2'].dt.day_name() == 'Sunday'].categoryId.value_counts().index[0]
answer
# Out:
# 24

# %% [markdown]
# **Question 5**
#
# 각 요일별 인기 영상들의 categoryId는 각각 몇개 씩인지 하나의 데이터 프레임으로 표현하라.

# %%
df
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
# ✅
# df['trending_date2'].dt.day_name 과 categoryId 두 칼럼을 기준으로 groupping
group = df.groupby([df['trending_date2'].dt.day_name(), 'categoryId'], as_index=False).size()
answer = group.pivot(index='categoryId', columns='trending_date2')
answer
# Out:
#                  size
# trending_date2 Friday Monday Saturday Sunday Thursday Tuesday Wednesday
# categoryId
# 1                 243    263      255    274      246     257       234
# 2                 120    105      119     99      128     119       129
# 10                833    837      776    830      890     894       917
# 15                187    215      198    217      207     208       207
# 17                633    668      592    636      682     708       706
# 19                 90     92       87     91       92      89        85
# 20                283    298      296    289      282     285       291
# 22               1288   1373     1289   1337     1341    1375      1333
# 23                568    594      570    556      560     569       566
# 24               2976   3148     3066   3096     2954    3084      3090
# 25                444    453      422    437      470     452       468
# 26                369    378      364    363      375     394       385
# ...

# %%
# My Answer
df['dayName'] = df['trending_date2'].dt.day_name()
answer = df.pivot_table(index='categoryId', columns='dayName', aggfunc='size')
answer
# Out:
# dayName     Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# categoryId
# 1              243     263       255     274       246      257        234
# 2              120     105       119      99       128      119        129
# 10             833     837       776     830       890      894        917
# 15             187     215       198     217       207      208        207
# 17             633     668       592     636       682      708        706
# 19              90      92        87      91        92       89         85
# 20             283     298       296     289       282      285        291
# 22            1288    1373      1289    1337      1341     1375       1333
# 23             568     594       570     556       560      569        566
# 24            2976    3148      3066    3096      2954     3084       3090
# 25             444     453       422     437       470      452        468
# ...

# %% [markdown]
# **Question 6**
#
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다. view count 대비 댓글수가 가장 높은 영상을 확인하라. (view_count값이 0인 경우는 제외한다.)

# %%
# ✅
# view_count 대비 댓글수 : comment_count / view_count

# 1. target 필터링 (view_count != 0)
target = df.loc[df.view_count != 0]
# 2. ratio 산출을 위한 df copy
target2 = target.copy()
# 3. ratio 산출
target2['ratio'] = (target2['comment_count'] / target2['view_count']).dropna()
# 4. 집계
answer = target2.sort_values('ratio', ascending=False).iloc[0].title
answer
# Out:
# '60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)'

# %% [markdown]
# **Question 7**
#
# 댓글의 수로 (comment_count) 영상 반응에 대한 판단을 할 수 있다. view count 대비 댓글수가 가장 낮은 영상을 확인하라. (view_counts, ratio값이 0인경우는 제외한다.)

# %%
ratio = (target2['comment_count'] / target2['view_count']).dropna().sort_values()
ratio[ratio != 0].index[0]

answer = df.iloc[ratio[ratio != 0].index[0]].title
answer
# Out:
# 'Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts'

# %%
# My Answer
target = df.loc[df.view_count != 0]
target2 = target.copy()
target2['ratio'] = (target2['comment_count'] / target2['view_count']).dropna()
answer = target2[target2['ratio'] != 0].sort_values('ratio').iloc[0].title
answer
# Out:
# 'Join the BTS #PermissiontoDance Challenge only on YouTube #Shorts'

# %% [markdown]
# **Question 8**
#
# like 대비 dislike의 수가 가장 적은 영상은 무엇인가? (like, dislike 값이 0인 경우는 제외한다.)

# %%
target = df.loc[(df.likes != 0) & (df.dislikes != 0)]
num = (target['dislikes']/target['likes']).sort_values().index[0]

answer = df.iloc[num].title
answer
# Out:
# '[줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰'

# %%
# My Answer
target = df.loc[(df.likes != 0) & (df.dislikes != 0)]
target2 = target.copy()
target2['ratio'] = (target2['likes'] / target2['dislikes']).dropna()
answer = target2.sort_values('ratio', ascending=False).iloc[0].title
answer
# Out:
# '[줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰'

# %% [markdown]
# **Question 9**
#
# 가장 많은 트렌드 영상을 제작한 채널의 이름은 무엇인가? (날짜기준, 중복포함)

# %%
answer = df.loc[df.channelId == df.channelId.value_counts().index[0]].channelTitle.unique()[0]
answer
# Out:
# '짤툰'

# %%
# My Answer
answer = df[df['channelId'] == df['channelId'].value_counts().index[0]].iloc[0].channelTitle
answer
# Out:
# '짤툰'

# %% [markdown]
# **Question 10**
#
# 20회(20일)이상 인기동영상 리스트에 포함된 동영상의 숫자는?

# %%
# ✅
answer = (df[['title', 'channelId']].value_counts() >= 20).sum()
answer
# Out:
# 40
